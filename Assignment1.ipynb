# %%
item_name = "Notebook"
print(item_name)
print(type(item_name))
item_name = 101
print(item_name)
print(type(item_name))
# Out:
# Notebook
# <class 'str'>
# 101
# <class 'int'>

# %%
name = "Ananya"
roll_number = 21
height_in_cm = 152.5
is_hostel_student = True
print("Name:", name)
print("Roll Number:", roll_number)
print("Height in cm:", height_in_cm)
print("Hostel Student:", is_hostel_student)
# Out:
# Name: Ananya
# Roll Number: 21
# Height in cm: 152.5
# Hostel Student: True

# %%
sam_age = 20
priya_age = 20
print(sam_age is priya_age )
print(sam_age == priya_age)
# Out:
# True
# True

# %%
raw_name = "  rohan MEHTA"
raw_name = raw_name.strip()
raw_name = raw_name.title()
print(raw_name)
# Out:
# Rohan Mehta

# %%
for i in range(1 , 7):
 print("Day" ,{i},": Watered the plant")
# Out:
# Day {1} : Watered the plant
# Day {2} : Watered the plant
# Day {3} : Watered the plant
# Day {4} : Watered the plant
# Day {5} : Watered the plant
# Day {6} : Watered the plant

# %%
i = 5
while i > 0:
  print(i)
  i -= 1
print("Blast off!")
# Out:
# 5
# 4
# 3
# 2
# 1
# Blast off!

# %%
age = 10
if age < 12:
    print("Ticket Price: ₹100")
else:
    print("Ticket Price: ₹250")
age = 15
if age < 12:
    print("Ticket Price: ₹100")
else:
    print("Ticket Price: ₹250")
# Out:
# Ticket Price: ₹100
# Ticket Price: ₹250

# %%
roll_number = 23
if roll_number % 10 == 0 :
    print("Even roll number ")
else:
    print("odd roll number")
# Out:
# odd roll number

# %%
def greet_student(name):
    print("Hello,", name + "! Welcome to Python class.")
greet_student("Meera")
greet_student("Karan")
# Out:
# Hello, Meera! Welcome to Python class.
# Hello, Karan! Welcome to Python class.

# %%
def add_number(a,b):
  print(a+b)
add_number(4,7)
# Out:
# 11

# %%
total_students = 0
def mark_present():
    global total_students
    total_students += 1
mark_present()
mark_present()
mark_present()
print(total_students)
# Out:
# 3

# %%
import pandas as pd
df = pd.DataFrame({
    "Month": ["January", "February", "March", "April", "May", "June"],
    "Actual Revenue": [50000, 55000, 60000, 58000, 65000, 70000],
    "Predicted Revenue": [48500, 56200, 59100, 57500, 64700, 71000]
})
df["Error"] = df["Predicted Revenue"] - df["Actual Revenue"]
print(df)
# Out:
#       Month  Actual Revenue  Predicted Revenue  Error
# 0   January           50000              48500  -1500
# 1  February           55000              56200   1200
# 2     March           60000              59100   -900
# 3     April           58000              57500   -500
# 4       May           65000              64700   -300
# 5      June           70000              71000   1000
